# %%
Ans 1. Following are the difference between Descriptive and Infrential Statistics are:
     . Infrential Statistics consist of using data you have measure to form conclusion While Discriptive Statistics consists of organising and 
     summarizing the data.
     . Infrential statistics draw conclusion of the data obtained while discriptive  result is in the form of table, graph.
Ans 2. P value is the probability of an observerved result assuming that the null hypothesis is true.
       If p-value ≤ alpha, you reject the null hypothesis in favor of the alternative hypothesis. 
       If p-value > alpha, you fail to reject the null hypothesis.
       Thus, the P value higher than the confidence that the null hypothesid was wrong(rejected).
Ans 3. a. It measure the spread or dispersion of data.
Ans 4. a. 3*4
Ans 5. option a
Ans 6. b. To estimate the population mean or proportion with a margin of error.
Ans 10. Orthogonal matrix  is a product of a sq matrix and its transpose gives an identity matrix then the sq matrix is known as orthogonal matrix.
        And its computational applications are:
        Coding Theory: In error-correcting codes and cryptography, orthogonal matrices play a role in encoding and decoding information 
        for secure and efficient data transmission.
        Numerical Stability: In numerical computations, orthogonal matrices are numerically stable. When you multiply an orthogonal matrix with its transpose, you get the identity matrix.
Ans 11. A matrix is like rectangulare(n*m) or sq(n*n) format while Tensor is an n-dimensional array statisfying a particular transformation law or any matrix is a tensor of rank 2.

# %%
import pandas as pd
data=pd.read_csv(r"C:\Users\Anshu Kumari\Desktop\India Agriculture Crop Production.csv", encoding="latin1")
df=pd.DataFrame(data)
print("Data has been successfully imported")
df.head()
# Out:
# Data has been successfully imported
#                          State                  District      Crop     Year  \
# 0  Andaman and Nicobar Islands                  NICOBARS  Arecanut  2001-02
# 1  Andaman and Nicobar Islands                  NICOBARS  Arecanut  2002-03
# 2  Andaman and Nicobar Islands                  NICOBARS  Arecanut  2003-04
# 3  Andaman and Nicobar Islands  NORTH AND MIDDLE ANDAMAN  Arecanut  2001-02
# 4  Andaman and Nicobar Islands            SOUTH ANDAMANS  Arecanut  2002-03
#
#        Season    Area Area Units  Production Production Units     Yield
# 0      Kharif  1254.0    Hectare      2061.0           Tonnes  1.643541
# 1  Whole Year  1258.0    Hectare      2083.0           Tonnes  1.655803
# 2  Whole Year  1261.0    Hectare      1525.0           Tonnes  1.209358
# 3      Kharif  3100.0    Hectare      5239.0           Tonnes  1.690000
# 4  Whole Year  3105.0    Hectare      5267.0           Tonnes  1.696296

# %%
# Ans 7

import csv
from collections import Counter

# Load your dataset
data = []
with open(r"C:\Users\Anshu Kumari\Desktop\India Agriculture Crop Production.csv", 'r') as file:
    reader = csv.reader(file)
    next(reader) 
    for row in reader:
        try:
            value = float(row[5])  # Convert to float instead of int
            data.append(value)
        except (ValueError, IndexError):
            
            pass

# Calculate Mean
def cal_mean(data):
    total = sum(data)
    mean = total / len(data)
    return mean
mean = cal_mean(data)

# Calculate Median
def cal_median(data):
    sorted_data = sorted(data)
    n = len(data)
    
    if n % 2 == 0:
        median = (sorted_data[n // 2 - 1] + sorted_data[n // 2]) / 2
    else:
        median = sorted_data[n // 2]
    return median
median = cal_median(data)

# Calculate Mode
def cal_mode(data):
     counts = Counter(data)
     mode = [k for k, v in counts.items() if v == max(counts.values())]
     return mode
mode = cal_mode(data)

# Print the mean, median, and mode values
print(f"Mean: {mean}")
print(f"Median: {median}")
print(f"Mode: {mode}")
